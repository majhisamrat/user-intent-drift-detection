# %%
import pandas as pd
import json
import re

# %%
train_df = pd.read_csv("data/raw/train.csv")
test_df = pd.read_csv("data/raw/test.csv")

# %%
train_df.sample(10)
# Out:
#                                                    text  \
# 979            Tell me the currencies that you support.
# 2369  I only got $20 of the $100 that I attempted to...
# 7308  What is this extra fee while I was doing a tra...
# 5828  I have checked my statements multiple times, b...
# 2370  Hi, I draw out some money from the ATM today. ...
# 2798               where has my transferred money gone?
# 5116         Is there a reason my payments are pending?
# 2907    what cards can i use to add money to my account
# 2265                           Is topping up unlimited?
# 5544  I tried to buy something online yesterday and ...
#
#                                 category
# 979                fiat_currency_support
# 2369       wrong_amount_of_cash_received
# 7308                transfer_fee_charged
# 5828               Refund_not_showing_up
# 2370       wrong_amount_of_cash_received
# 2798  transfer_not_received_by_recipient
# 5116                pending_card_payment
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10003 entries, 0 to 10002
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      10003 non-null  object
#  1   category  10003 non-null  object
# dtypes: object(2)
# memory usage: 156.4+ KB
